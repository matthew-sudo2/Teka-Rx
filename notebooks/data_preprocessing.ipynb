# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/450.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/450.1 MB ? eta -:--:--
#      ---------------------------------------- 1.8/450.1 MB 8.8 MB/s eta 0:00:52
#      ---------------------------------------- 3.7/450.1 MB 8.6 MB/s eta 0:00:53
#       --------------------------------------- 5.8/450.1 MB 9.3 MB/s eta 0:00:48
#       --------------------------------------- 7.6/450.1 MB 8.9 MB/s eta 0:00:50
#       --------------------------------------- 9.2/450.1 MB 8.6 MB/s eta 0:00:52
#       -------------------------------------- 10.7/450.1 MB 8.4 MB/s eta 0:00:53
#      - ------------------------------------- 12.3/450.1 MB 8.2 MB/s eta 0:00:54
#      - ------------------------------------- 14.2/450.1 MB 8.2 MB/s eta 0:00:54
#      - ------------------------------------- 15.7/450.1 MB 8.2 MB/s eta 0:00:54
# ...

# %%
import pandas as pd

df = pd.read_parquet("data\interim\faers\drug\2023Q3.parquet")

df.head(5)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\i'
# <>:3: SyntaxWarning: invalid escape sequence '\i'
# /tmp/ipykernel_1389/2332921858.py:3: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_parquet("data\interim\faers\drug\2023Q3.parquet")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1389/2332921858.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_parquet("data\interim\faers\drug\2023Q3.parquet")
#       4
#       5 df.head(5)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# ...
